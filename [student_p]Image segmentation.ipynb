# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy import misc

# %%
pip install opencv-contrib-python
# Out:
# ...
#
# ...
#      --------------------------------------- 42.5/42.5 MB 54.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 1. Create a list of possible combination of classes. For each possible combination, link it to a color or hue
#  <b>10 classes</b> <br>
# 10C3 = 120 <br>
# 10C4 = 210 <br>
# 10C5 = 252 <br>
# Q: - Feels like the order should matter? (In the combination, the most occured class followed by the next...)(Is there a difference between (1,2,3) (2,3,1))

# %% [markdown]
# ## 2. k- Nearest Neighbourhood pixel - (im: the image, (x,y):the center pixel, (nx,ny): the neighbourhood pixel size)
# Criteria: circular sampling instead of a grid, how to deal with edges(flip or take moving average), try sliding the pixel sampling to improve efficiency(sliding window )

# %%
# Just an ordinary neighbours function, currently in grid pattern, try changing to circular (incomplete)
def neighbours(im, x, y, nx=1, ny=1):
 return im[max(x-nx, 0) : min(x+nx+1, im.shape[0]), \ max(y-ny, 0) : min(y+ny+1, im.shape[1])]

# %%
## Version 1, incomplete
import cv2
import matplotlib.pyplot as plt
import numpy as np

# read the image and define the stepSize and window size 
# (width,height)
img = cv2.imread('H:\My Documents\cells.jpg') # your image path
tmp = img # for drawing a rectangle
stepSize = 50
(w_width, w_height) = (50, 50) # window size
for x in range(0, image.shape[1] - w_width , stepSize):
   for y in range(0, image.shape[0] - w_height, stepSize):
      window = image[x:x + w_width, y:y + w_height, :]
      
# classify content of the window with your classifier and  
# determine if the window includes an object (cell) or not
      # draw window on image
      cv2.rectangle(tmp, (x, y), (x + w_width, y + w_height), (255, 0, 0), 2) # draw rectangle on image
      plt.imshow(np.array(tmp).astype('uint8'))
# show all windows
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15944\895668670.py in <module>
#       9 stepSize = 50
#      10 (w_width, w_height) = (50, 50) # window size
# ---> 11 for x in range(0, image.shape[1] - w_width , stepSize):
#      12    for y in range(0, image.shape[0] - w_height, stepSize):
#      13       window = image[x:x + w_width, y:y + w_height, :]
#
# NameError: name 'image' is not defined

# %%
## Version 2 - Image Segmentation using K Clustering
import cv2
import matplotlib.pyplot as plt
import numpy as np

#In K-Means++, We pick a point randomly and that's your first centroid, then we pick the next point based on the 
#probability that depends upon the distance of the first point, the further apart the point is the more probable it is.


original_image = cv2.imread('H:\My Documents\RENAL01.jpg')
img=cv2.cvtColor(original_image,cv2.COLOR_BGR2RGB)

#Convert MxNx3 image into a Kx3 matrix where K=MxN and each row is now a vector in the 3-D space of RGB.
vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K =10
attempts=10
ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))
figure_size = 15
plt.figure(figsize=(figure_size,figure_size))
plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image)
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()

# %%
##3rd Attempt good old fashion Brute Force
#import image
original_image = cv2.imread('H:\My Documents\cells.jpg')
img=cv2.cvtColor(original_image,cv2.COLOR_BGR2RGB)
vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized)
h, w, c = img.shape

## create temp img with the dimensions of image
temp = np.array(original_image)
temp[0, 0, 0] = 0


## Create the HSV map

##image for sampling


## K represents the size of the sample width, make it an input
# Hypothesis, we segment the image give to us, creating a sub image. The center of the image is the main pixel we are classifying
# We do K mean Cluster on the Sub image, then we transform the central pixel based on the K mean cluster result
K=25;

# %%
##
for r = K in range(h-K): 
    for c = K in range(w-K):
        img[r][c].

    }
  }
# Out:
# width:   600
# height:  381
# channel: 3

# %% [markdown]
# ## 2. Histogram of most common combination
# Once we have a grid of possible values, we will  count how much of each combination that we have, ignore all black values (assume it is lines thus remove it)

# %%
def build_hist(im):
 hist = [0]*256
 for x in range(im.shape[0]):
 for y in range(im.shape[1]):
 gray_level = im[x,y]
 hist[gray_level] += 1
 return hist
